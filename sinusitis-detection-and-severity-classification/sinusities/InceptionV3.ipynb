# %%
# Import necessary libraries
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import seaborn as sns

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Set dataset directory path
dataset_path = '/content/drive/MyDrive/sinusities/sinusities_dataset'

# Enhanced Dataset Preprocessing with More Augmentations
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest',
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(299, 299),  # InceptionV3 input size
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

validation_generator = train_datagen.flow_from_directory(
    dataset_path,
    target_size=(299, 299),  # InceptionV3 input size
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

# Load Pre-Trained InceptionV3 Model
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))

# Build Custom Layers on Top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = BatchNormalization()(x)  # Added Batch Normalization
x = Dropout(0.5)(x)          # Dropout to reduce overfitting
x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = Dropout(0.3)(x)          # Additional Dropout for regularization
predictions = Dense(3, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Freeze Base Model Layers
for layer in base_model.layers:
    layer.trainable = False

# Compile the Model with a Warm-Up Learning Rate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),  # Start with a high learning rate for warm-up
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Callbacks for Training
callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss', factor=0.5, patience=3, min_lr=1e-7, verbose=1
    ),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=5, restore_best_weights=True, verbose=1
    )
]

# Train the Model
history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=25,  # Fewer epochs for warm-up
    callbacks=callbacks
)

# Fine-Tune the Model
# Gradually Unfreeze Layers for Fine-Tuning
for layer in base_model.layers[:249]:
    layer.trainable = False
for layer in base_model.layers[249:]:
    layer.trainable = True

# Recompile with a Lower Learning Rate
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the Fine-Tuned Model
fine_tune_history = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=25,
    callbacks=callbacks
)

# Save the Model
model.save('/content/drive/MyDrive/sinusities/inceptionv3.h5')

# Combine Histories for Visualization
history.history['accuracy'].extend(fine_tune_history.history['accuracy'])
history.history['val_accuracy'].extend(fine_tune_history.history['val_accuracy'])
history.history['loss'].extend(fine_tune_history.history['loss'])
history.history['val_loss'].extend(fine_tune_history.history['val_loss'])

# Plot Accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot Loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 1200 images belonging to 3 classes.
# Found 300 images belonging to 3 classes.
# Epoch 1/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 231s 5s/step - accuracy: 0.4884 - loss: 20.1373 - val_accuracy: 0.4900 - val_loss: 16.0992 - learning_rate: 0.0010
# Epoch 2/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 992ms/step - accuracy: 0.5292 - loss: 14.0287 - val_accuracy: 0.3667 - val_loss: 12.1168 - learning_rate: 0.0010
# Epoch 3/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.5586 - loss: 10.4393 - val_accuracy: 0.5400 - val_loss: 8.4514 - learning_rate: 0.0010
# Epoch 4/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 81s 963ms/step - accuracy: 0.5534 - loss: 8.0474 - val_accuracy: 0.5033 - val_loss: 6.8264 - learning_rate: 0.0010
# Epoch 5/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 943ms/step - accuracy: 0.6269 - loss: 6.2111 - val_accuracy: 0.4500 - val_loss: 5.6462 - learning_rate: 0.0010
# Epoch 6/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 948ms/step - accuracy: 0.6051 - loss: 5.0045 - val_accuracy: 0.5667 - val_loss: 4.3374 - learning_rate: 0.0010
# Epoch 7/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 964ms/step - accuracy: 0.6087 - loss: 4.0908 - val_accuracy: 0.5900 - val_loss: 3.6350 - learning_rate: 0.0010
# Epoch 8/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 81s 991ms/step - accuracy: 0.6144 - loss: 3.4604 - val_accuracy: 0.4933 - val_loss: 3.3361 - learning_rate: 0.0010
# Epoch 9/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.6355 - loss: 2.9592 - val_accuracy: 0.5933 - val_loss: 2.7202 - learning_rate: 0.0010
# Epoch 10/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 997ms/step - accuracy: 0.6531 - loss: 2.5246 - val_accuracy: 0.5500 - val_loss: 2.5507 - learning_rate: 0.0010
# Epoch 11/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.6723 - loss: 2.1773 - val_accuracy: 0.5700 - val_loss: 2.1990 - learning_rate: 0.0010
# Epoch 12/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.6517 - loss: 2.0147 - val_accuracy: 0.5867 - val_loss: 1.9926 - learning_rate: 0.0010
# Epoch 13/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 81s 968ms/step - accuracy: 0.6400 - loss: 1.8309 - val_accuracy: 0.6367 - val_loss: 1.7426 - learning_rate: 0.0010
# Epoch 14/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.6637 - loss: 1.6600 - val_accuracy: 0.5867 - val_loss: 1.7232 - learning_rate: 0.0010
# Epoch 15/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.6471 - loss: 1.5701 - val_accuracy: 0.4867 - val_loss: 1.9097 - learning_rate: 0.0010
# Epoch 16/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.6364 - loss: 1.5051 - val_accuracy: 0.4567 - val_loss: 2.3521 - learning_rate: 0.0010
# Epoch 17/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 81s 964ms/step - accuracy: 0.6226 - loss: 1.4255 - val_accuracy: 0.5667 - val_loss: 1.7173 - learning_rate: 0.0010
# Epoch 18/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 955ms/step - accuracy: 0.6295 - loss: 1.3628 - val_accuracy: 0.5733 - val_loss: 1.3839 - learning_rate: 0.0010
# Epoch 19/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 992ms/step - accuracy: 0.6728 - loss: 1.2825 - val_accuracy: 0.5333 - val_loss: 1.5016 - learning_rate: 0.0010
# Epoch 20/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 987ms/step - accuracy: 0.6432 - loss: 1.2905 - val_accuracy: 0.4933 - val_loss: 1.5764 - learning_rate: 0.0010
# Epoch 21/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 750ms/step - accuracy: 0.6318 - loss: 1.2630
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.6323 - loss: 1.2627 - val_accuracy: 0.5533 - val_loss: 1.5131 - learning_rate: 0.0010
# Epoch 22/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 81s 948ms/step - accuracy: 0.6584 - loss: 1.1788 - val_accuracy: 0.6233 - val_loss: 1.2293 - learning_rate: 5.0000e-04
# Epoch 23/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 84s 1s/step - accuracy: 0.6837 - loss: 1.1032 - val_accuracy: 0.5133 - val_loss: 1.3912 - learning_rate: 5.0000e-04
# Epoch 24/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 42s 978ms/step - accuracy: 0.6823 - loss: 1.0709 - val_accuracy: 0.5633 - val_loss: 1.2438 - learning_rate: 5.0000e-04
# Epoch 25/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 971ms/step - accuracy: 0.6976 - loss: 1.0093 - val_accuracy: 0.6367 - val_loss: 1.1466 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 25.
# Epoch 1/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 95s 2s/step - accuracy: 0.6094 - loss: 1.1581 - val_accuracy: 0.6033 - val_loss: 1.1467 - learning_rate: 1.0000e-05
# Epoch 2/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - accuracy: 0.6160 - loss: 1.0923 - val_accuracy: 0.6100 - val_loss: 1.0888 - learning_rate: 1.0000e-05
# Epoch 3/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 949ms/step - accuracy: 0.6649 - loss: 1.0394 - val_accuracy: 0.6100 - val_loss: 1.1311 - learning_rate: 1.0000e-05
# Epoch 4/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.7284 - loss: 0.9392 - val_accuracy: 0.6500 - val_loss: 1.0388 - learning_rate: 1.0000e-05
# Epoch 5/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.7075 - loss: 0.9551 - val_accuracy: 0.7000 - val_loss: 0.9600 - learning_rate: 1.0000e-05
# Epoch 6/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.7380 - loss: 0.8973 - val_accuracy: 0.6733 - val_loss: 0.9746 - learning_rate: 1.0000e-05
# Epoch 7/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 977ms/step - accuracy: 0.7530 - loss: 0.8823 - val_accuracy: 0.6933 - val_loss: 0.9821 - learning_rate: 1.0000e-05
# Epoch 8/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 84s 996ms/step - accuracy: 0.7686 - loss: 0.8347 - val_accuracy: 0.7200 - val_loss: 0.9268 - learning_rate: 1.0000e-05
# Epoch 9/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.7916 - loss: 0.8077 - val_accuracy: 0.7400 - val_loss: 0.8914 - learning_rate: 1.0000e-05
# Epoch 10/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.7941 - loss: 0.7899 - val_accuracy: 0.7333 - val_loss: 0.8589 - learning_rate: 1.0000e-05
# Epoch 11/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8069 - loss: 0.7588 - val_accuracy: 0.7200 - val_loss: 0.8483 - learning_rate: 1.0000e-05
# Epoch 12/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 1s/step - accuracy: 0.8122 - loss: 0.7782 - val_accuracy: 0.7267 - val_loss: 0.8650 - learning_rate: 1.0000e-05
# Epoch 13/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.8229 - loss: 0.7504 - val_accuracy: 0.7733 - val_loss: 0.8327 - learning_rate: 1.0000e-05
# Epoch 14/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.7885 - loss: 0.7627 - val_accuracy: 0.7433 - val_loss: 0.8926 - learning_rate: 1.0000e-05
# Epoch 15/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.8267 - loss: 0.6893 - val_accuracy: 0.7833 - val_loss: 0.8235 - learning_rate: 1.0000e-05
# Epoch 16/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step - accuracy: 0.8260 - loss: 0.7094 - val_accuracy: 0.7567 - val_loss: 0.8211 - learning_rate: 1.0000e-05
# Epoch 17/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 81s 963ms/step - accuracy: 0.8291 - loss: 0.7208 - val_accuracy: 0.7567 - val_loss: 0.8822 - learning_rate: 1.0000e-05
# Epoch 18/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 957ms/step - accuracy: 0.8708 - loss: 0.6447 - val_accuracy: 0.8067 - val_loss: 0.7562 - learning_rate: 1.0000e-05
# Epoch 19/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 44s 969ms/step - accuracy: 0.8445 - loss: 0.6584 - val_accuracy: 0.7500 - val_loss: 0.8137 - learning_rate: 1.0000e-05
# Epoch 20/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 83s 1s/step - accuracy: 0.8440 - loss: 0.6648 - val_accuracy: 0.7433 - val_loss: 0.8634 - learning_rate: 1.0000e-05
# Epoch 21/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 0s 747ms/step - accuracy: 0.8384 - loss: 0.6646
# Epoch 21: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 992ms/step - accuracy: 0.8386 - loss: 0.6641 - val_accuracy: 0.7833 - val_loss: 0.7597 - learning_rate: 1.0000e-05
# Epoch 22/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 82s 976ms/step - accuracy: 0.8570 - loss: 0.6181 - val_accuracy: 0.7867 - val_loss: 0.7603 - learning_rate: 5.0000e-06
# Epoch 23/25
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 43s 953ms/step - accuracy: 0.8743 - loss: 0.6056 - val_accuracy: 0.7967 - val_loss: 0.7953 - learning_rate: 5.0000e-06
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 18.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
